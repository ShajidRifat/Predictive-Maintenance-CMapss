# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
test_df=pd.read_csv("CMaps/test_FD001.txt", sep=' ', header=None)
test_df
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1  0.0023  0.0003  100.0  518.67  643.02  1585.29  1398.21
# 1        1    2 -0.0027 -0.0003  100.0  518.67  641.71  1588.45  1395.42
# 2        1    3  0.0003  0.0001  100.0  518.67  642.46  1586.94  1401.34
# 3        1    4  0.0042  0.0000  100.0  518.67  642.44  1584.12  1406.42
# 4        1    5  0.0014  0.0000  100.0  518.67  642.51  1587.19  1401.92
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 13091  100  194  0.0049  0.0000  100.0  518.67  643.24  1599.45  1415.79
# 13092  100  195 -0.0011 -0.0001  100.0  518.67  643.22  1595.69  1422.05
# 13093  100  196 -0.0006 -0.0003  100.0  518.67  643.44  1593.15  1406.82
# 13094  100  197 -0.0038  0.0001  100.0  518.67  643.26  1594.99  1419.36
# 13095  100  198  0.0013  0.0003  100.0  518.67  642.95  1601.62  1424.99
#
#           9   ...       18      19    20   21    22     23     24       25  \
# ...

# %%
train_df=pd.read_csv("CMaps/train_FD001.txt",sep=' ',header=None)
train_df
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...       18      19    20   21    22     23     24       25  \
# ...

# %%
columns = [
    "unit_number", "time_in_cycles", "setting_1", "setting_2", "TRA",
    "T2", "T24", "T30", "T50", "P2", "P15", "P30", "Nf", "Nc", "epr",
    "Ps30", "phi", "NRf", "NRc", "BPR", "farB", "htBleed", "Nf_dmd",
    "PCNfR_dmd", "W31", "W32"
]

# %%
def load_and_clean_data(filepath):
    df = pd.read_csv(filepath, sep=" ", header=None)
    df = df.drop([26, 27], axis="columns", errors="ignore")
    df.columns = columns
    return df


train_df = load_and_clean_data("CMaps/train_FD001.txt")
train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0007    -0.0004  100.0  518.67
# 1                1               2     0.0019    -0.0003  100.0  518.67
# 2                1               3    -0.0043     0.0003  100.0  518.67
# 3                1               4     0.0007     0.0000  100.0  518.67
# 4                1               5    -0.0019    -0.0002  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 20626          100             196    -0.0004    -0.0003  100.0  518.67
# 20627          100             197    -0.0016    -0.0005  100.0  518.67
# 20628          100             198     0.0004     0.0000  100.0  518.67
# 20629          100             199    -0.0011     0.0003  100.0  518.67
# 20630          100             200    -0.0032    -0.0005  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# ...

# %%
test_df = load_and_clean_data("CMaps/test_FD001.txt")
test_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1     0.0023     0.0003  100.0  518.67
# 1                1               2    -0.0027    -0.0003  100.0  518.67
# 2                1               3     0.0003     0.0001  100.0  518.67
# 3                1               4     0.0042     0.0000  100.0  518.67
# 4                1               5     0.0014     0.0000  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 13091          100             194     0.0049     0.0000  100.0  518.67
# 13092          100             195    -0.0011    -0.0001  100.0  518.67
# 13093          100             196    -0.0006    -0.0003  100.0  518.67
# 13094          100             197    -0.0038     0.0001  100.0  518.67
# 13095          100             198     0.0013     0.0003  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# ...

# %%
train_df.describe()
# Out:
#         unit_number  time_in_cycles     setting_1     setting_2      TRA  \
# count  20631.000000    20631.000000  20631.000000  20631.000000  20631.0
# mean      51.506568      108.807862     -0.000009      0.000002    100.0
# std       29.227633       68.880990      0.002187      0.000293      0.0
# min        1.000000        1.000000     -0.008700     -0.000600    100.0
# 25%       26.000000       52.000000     -0.001500     -0.000200    100.0
# 50%       52.000000      104.000000      0.000000      0.000000    100.0
# 75%       77.000000      156.000000      0.001500      0.000300    100.0
# max      100.000000      362.000000      0.008700      0.000600    100.0
#
#                  T2           T24           T30           T50            P2  \
# count  2.063100e+04  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean   5.186700e+02    642.680934   1590.523119   1408.933782  1.462000e+01
# std    6.537152e-11      0.500053      6.131150      9.000605  3.394700e-12
# ...

# %%
test_df.describe()
# Out:
#         unit_number  time_in_cycles     setting_1     setting_2      TRA  \
# count  13096.000000    13096.000000  13096.000000  13096.000000  13096.0
# mean      51.543907       76.836515     -0.000011      0.000004    100.0
# std       28.289423       53.057749      0.002203      0.000294      0.0
# min        1.000000        1.000000     -0.008200     -0.000600    100.0
# 25%       28.000000       33.000000     -0.001500     -0.000200    100.0
# 50%       52.000000       69.000000     -0.000000     -0.000000    100.0
# 75%       76.000000      113.000000      0.001500      0.000300    100.0
# max      100.000000      303.000000      0.007800      0.000700    100.0
#
#                  T2           T24           T30           T50            P2  \
# count  1.309600e+04  13096.000000  13096.000000  13096.000000  1.309600e+04
# mean   5.186700e+02    642.475088   1588.099204   1404.735362  1.462000e+01
# std    6.014263e-11      0.400899      5.003274      6.688309  2.671743e-12
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(train_df.corr(), cmap="coolwarm", annot=False)
plt.title("Sensor Correlation Heatmap (FD001)")
plt.show()

# %%
eol_train = []
for engine_id in train_df['unit_number']:
    max_cycle = train_df[train_df['unit_number'] == engine_id]['time_in_cycles'].max()
    eol_train.append(max_cycle)

train_df['EOL'] = eol_train
train_df['LR'] = train_df['time_in_cycles'] / train_df['EOL']

train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0007    -0.0004  100.0  518.67
# 1                1               2     0.0019    -0.0003  100.0  518.67
# 2                1               3    -0.0043     0.0003  100.0  518.67
# 3                1               4     0.0007     0.0000  100.0  518.67
# 4                1               5    -0.0019    -0.0002  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 20626          100             196    -0.0004    -0.0003  100.0  518.67
# 20627          100             197    -0.0016    -0.0005  100.0  518.67
# 20628          100             198     0.0004     0.0000  100.0  518.67
# 20629          100             199    -0.0011     0.0003  100.0  518.67
# 20630          100             200    -0.0032    -0.0005  100.0  518.67
#
#           T24      T30      T50     P2  ...      NRc     BPR  farB  htBleed  \
# ...

# %%
rul_data = pd.read_csv('CMaps/RUL_FD001.txt', sep=' ', header=None)
rul_data = rul_data.drop([1], axis='columns').values


eol_test = []
for engine_id in test_df['unit_number']:
    cycles_run = len(test_df[test_df['unit_number'] == engine_id])
    actual_rul = rul_data[engine_id - 1][0]
    eol_test.append(cycles_run + actual_rul)

test_df['EOL'] = eol_test
test_df['LR'] = test_df['time_in_cycles'] / test_df['EOL']

test_df.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2    TRA      T2     T24  \
# 0            1               1     0.0023     0.0003  100.0  518.67  643.02
# 1            1               2    -0.0027    -0.0003  100.0  518.67  641.71
# 2            1               3     0.0003     0.0001  100.0  518.67  642.46
# 3            1               4     0.0042     0.0000  100.0  518.67  642.44
# 4            1               5     0.0014     0.0000  100.0  518.67  642.51
#
#        T30      T50     P2  ...      NRc     BPR  farB  htBleed  Nf_dmd  \
# 0  1585.29  1398.21  14.62  ...  8125.55  8.4052  0.03      392    2388
# 1  1588.45  1395.42  14.62  ...  8139.62  8.3803  0.03      393    2388
# 2  1586.94  1401.34  14.62  ...  8130.10  8.4441  0.03      393    2388
# 3  1584.12  1406.42  14.62  ...  8132.90  8.3917  0.03      391    2388
# 4  1587.19  1401.92  14.62  ...  8129.54  8.4031  0.03      390    2388
#
#    PCNfR_dmd    W31      W32  EOL        LR
# ...

# %%
def assign_labels(df):
    """Categorizes engine health based on Life Ratio."""
    labels = []
    for lr in df['LR']:
        if lr <= 0.6:
            labels.append(0)
        elif lr <= 0.8:
            labels.append(1)
        else:
            labels.append(2)

    df['labels'] = labels

    return df.drop(columns=['unit_number', 'EOL', 'LR'])

train_model_data = assign_labels(train_df)
test_model_data  = assign_labels(test_df)

train_model_data.head()
# Out:
#    time_in_cycles  setting_1  setting_2    TRA      T2     T24      T30  \
# 0               1    -0.0007    -0.0004  100.0  518.67  641.82  1589.70
# 1               2     0.0019    -0.0003  100.0  518.67  642.15  1591.82
# 2               3    -0.0043     0.0003  100.0  518.67  642.35  1587.99
# 3               4     0.0007     0.0000  100.0  518.67  642.35  1582.79
# 4               5    -0.0019    -0.0002  100.0  518.67  642.37  1582.85
#
#        T50     P2    P15  ...      NRf      NRc     BPR  farB  htBleed  \
# 0  1400.60  14.62  21.61  ...  2388.02  8138.62  8.4195  0.03      392
# 1  1403.14  14.62  21.61  ...  2388.07  8131.49  8.4318  0.03      392
# 2  1404.20  14.62  21.61  ...  2388.03  8133.23  8.4178  0.03      390
# 3  1401.87  14.62  21.61  ...  2388.08  8133.83  8.3682  0.03      392
# 4  1406.22  14.62  21.61  ...  2388.04  8133.80  8.4294  0.03      393
#
#    Nf_dmd  PCNfR_dmd    W31      W32  labels
# 0    2388      100.0  39.06  23.4190       0
# ...

# %%
train_model_data.describe()
# Out:
#        time_in_cycles     setting_1     setting_2      TRA            T2  \
# count    20631.000000  20631.000000  20631.000000  20631.0  2.063100e+04
# mean       108.807862     -0.000009      0.000002    100.0  5.186700e+02
# std         68.880990      0.002187      0.000293      0.0  6.537152e-11
# min          1.000000     -0.008700     -0.000600    100.0  5.186700e+02
# 25%         52.000000     -0.001500     -0.000200    100.0  5.186700e+02
# 50%        104.000000      0.000000      0.000000    100.0  5.186700e+02
# 75%        156.000000      0.001500      0.000300    100.0  5.186700e+02
# max        362.000000      0.008700      0.000600    100.0  5.186700e+02
#
#                 T24           T30           T50            P2           P15  \
# count  20631.000000  20631.000000  20631.000000  2.063100e+04  20631.000000
# mean     642.680934   1590.523119   1408.933782  1.462000e+01     21.609803
# std        0.500053      6.131150      9.000605  3.394700e-12      0.001389
# ...

# %%
test_model_data.describe()
# Out:
#        time_in_cycles     setting_1     setting_2      TRA            T2  \
# count    13096.000000  13096.000000  13096.000000  13096.0  1.309600e+04
# mean        76.836515     -0.000011      0.000004    100.0  5.186700e+02
# std         53.057749      0.002203      0.000294      0.0  6.014263e-11
# min          1.000000     -0.008200     -0.000600    100.0  5.186700e+02
# 25%         33.000000     -0.001500     -0.000200    100.0  5.186700e+02
# 50%         69.000000     -0.000000     -0.000000    100.0  5.186700e+02
# 75%        113.000000      0.001500      0.000300    100.0  5.186700e+02
# max        303.000000      0.007800      0.000700    100.0  5.186700e+02
#
#                 T24           T30           T50            P2           P15  \
# count  13096.000000  13096.000000  13096.000000  1.309600e+04  13096.000000
# mean     642.475088   1588.099204   1404.735362  1.462000e+01     21.609701
# std        0.400899      5.003274      6.688309  2.671743e-12      0.001704
# ...

# %%
zero_variance_cols = train_model_data.columns[train_model_data.std() < 0.01]
print("Dropped flatline sensors:", list(zero_variance_cols))
# Out:
# Dropped flatline sensors: ['setting_1', 'setting_2', 'TRA', 'T2', 'P2', 'P15', 'epr', 'farB', 'Nf_dmd', 'PCNfR_dmd']

# %%
train_model_data = train_model_data.drop(columns=zero_variance_cols)
test_model_data = test_model_data.drop(columns=zero_variance_cols, errors='ignore')

# %%
train_model_data
# Out:
#        time_in_cycles     T24      T30      T50     P30       Nf       Nc  \
# 0                   1  641.82  1589.70  1400.60  554.36  2388.06  9046.19
# 1                   2  642.15  1591.82  1403.14  553.75  2388.04  9044.07
# 2                   3  642.35  1587.99  1404.20  554.26  2388.08  9052.94
# 3                   4  642.35  1582.79  1401.87  554.45  2388.11  9049.48
# 4                   5  642.37  1582.85  1406.22  554.00  2388.06  9055.15
# ...               ...     ...      ...      ...     ...      ...      ...
# 20626             196  643.49  1597.98  1428.63  551.43  2388.19  9065.52
# 20627             197  643.54  1604.50  1433.58  550.86  2388.23  9065.11
# 20628             198  643.42  1602.46  1428.18  550.94  2388.24  9065.90
# 20629             199  643.23  1605.26  1426.53  550.68  2388.25  9073.72
# 20630             200  643.85  1600.38  1432.14  550.79  2388.26  9061.48
#
#         Ps30     phi      NRf      NRc     BPR  htBleed    W31      W32  \
# ...

# %%
test_model_data
# Out:
#        time_in_cycles     T24      T30      T50     P30       Nf       Nc  \
# 0                   1  643.02  1585.29  1398.21  553.90  2388.04  9050.17
# 1                   2  641.71  1588.45  1395.42  554.85  2388.01  9054.42
# 2                   3  642.46  1586.94  1401.34  554.11  2388.05  9056.96
# 3                   4  642.44  1584.12  1406.42  554.07  2388.03  9045.29
# 4                   5  642.51  1587.19  1401.92  554.16  2388.01  9044.55
# ...               ...     ...      ...      ...     ...      ...      ...
# 13091             194  643.24  1599.45  1415.79  553.41  2388.02  9142.37
# 13092             195  643.22  1595.69  1422.05  553.22  2388.05  9140.68
# 13093             196  643.44  1593.15  1406.82  553.04  2388.11  9146.81
# 13094             197  643.26  1594.99  1419.36  553.37  2388.07  9148.85
# 13095             198  642.95  1601.62  1424.99  552.48  2388.06  9155.03
#
#         Ps30     phi      NRf      NRc     BPR  htBleed    W31      W32  \
# ...

# %%
sensor_cols = [col for col in train_model_data.columns if col != 'labels']

# %%
for col in sensor_cols:
    train_model_data[f"{col}_rolling_mean"] = train_model_data[col].rolling(window=5, min_periods=1).mean()

# %%
for col in sensor_cols:
    test_model_data[f"{col}_rolling_mean"] = test_model_data[col].rolling(window=5, min_periods=1).mean()

# %%
X_train = train_model_data.drop(columns=['labels'])
y_train = train_model_data['labels']

X_test = test_model_data.drop(columns=['labels'])
y_test = test_model_data['labels']

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
model = RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = model.predict(X_test_scaled)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9053145998778253

# %%
cm = confusion_matrix(y_test, y_pred)
# Plot it beautifully
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Good (0)', 'Moderate (1)', 'Warning (2)'], 
            yticklabels=['Good (0)', 'Moderate (1)', 'Warning (2)'])
plt.xlabel('What the Model Predicted')
plt.ylabel('The Actual Truth')
plt.title('Classification Confusion Matrix')
plt.show()

# %%
# HYPERPARAMETER TUNING

from sklearn.model_selection import RandomizedSearchCV

print("\nSearching for the best Random Forest parameters...")

# 1. Define the grid of settings to test
param_dist = {
    "n_estimators": [50, 100, 200],
    "max_depth": [10, 20, None],
    "min_samples_split": [2, 5, 10]
}

# 2. Run the search (Testing different combinations)
random_search = RandomizedSearchCV(
    RandomForestClassifier(random_state=42),
    param_distributions=param_dist,
    n_iter=5, # Number of random combinations to try
    cv=3,
    scoring="accuracy", # Again, accuracy instead of error!
    random_state=42,
    n_jobs=-1
)
random_search.fit(X_train_scaled, y_train)

# 3. Save the absolute best model it found
best_rf_model = random_search.best_estimator_

print(f"Best Parameters Found: {random_search.best_params_}")
# Out:
# Searching for the best Random Forest parameters...
# Best Parameters Found: {'n_estimators': 200, 'min_samples_split': 10, 'max_depth': 10}

# %%
train_df = load_and_clean_data("CMaps/train_FD001.txt")
train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0007    -0.0004  100.0  518.67
# 1                1               2     0.0019    -0.0003  100.0  518.67
# 2                1               3    -0.0043     0.0003  100.0  518.67
# 3                1               4     0.0007     0.0000  100.0  518.67
# 4                1               5    -0.0019    -0.0002  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 20626          100             196    -0.0004    -0.0003  100.0  518.67
# 20627          100             197    -0.0016    -0.0005  100.0  518.67
# 20628          100             198     0.0004     0.0000  100.0  518.67
# 20629          100             199    -0.0011     0.0003  100.0  518.67
# 20630          100             200    -0.0032    -0.0005  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# ...

# %%
train_df = load_and_clean_data("CMaps/train_FD002.txt")
train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    34.9983     0.8400  100.0  449.44
# 1                1               2    41.9982     0.8408  100.0  445.00
# 2                1               3    24.9988     0.6218   60.0  462.54
# 3                1               4    42.0077     0.8416  100.0  445.00
# 4                1               5    25.0005     0.6203   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 53754          260             312    20.0037     0.7000  100.0  491.19
# 53755          260             313    10.0022     0.2510  100.0  489.05
# 53756          260             314    25.0041     0.6200   60.0  462.54
# 53757          260             315    25.0033     0.6220   60.0  462.54
# 53758          260             316    35.0036     0.8400  100.0  449.44
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc  \
# ...

# %%
train_df = load_and_clean_data("CMaps/train_FD003.txt")
train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0005     0.0004  100.0  518.67
# 1                1               2     0.0008    -0.0003  100.0  518.67
# 2                1               3    -0.0014    -0.0002  100.0  518.67
# 3                1               4    -0.0020     0.0001  100.0  518.67
# 4                1               5     0.0016     0.0000  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 24715          100             148    -0.0016    -0.0003  100.0  518.67
# 24716          100             149     0.0034    -0.0003  100.0  518.67
# 24717          100             150    -0.0016     0.0004  100.0  518.67
# 24718          100             151    -0.0023     0.0004  100.0  518.67
# 24719          100             152     0.0000     0.0003  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# ...

# %%
train_df = load_and_clean_data("CMaps/train_FD004.txt")
train_df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    42.0049     0.8400  100.0  445.00
# 1                1               2    20.0020     0.7002  100.0  491.19
# 2                1               3    42.0038     0.8409  100.0  445.00
# 3                1               4    42.0000     0.8400  100.0  445.00
# 4                1               5    25.0063     0.6207   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 61244          249             251     9.9998     0.2500  100.0  489.05
# 61245          249             252     0.0028     0.0015  100.0  518.67
# 61246          249             253     0.0029     0.0000  100.0  518.67
# 61247          249             254    35.0046     0.8400  100.0  449.44
# 61248          249             255    42.0030     0.8400  100.0  445.00
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc  \
# ...
